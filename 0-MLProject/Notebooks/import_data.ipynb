# %% [markdown]
# # NOTEBOOK 1

# %% [markdown]
# ### - En este notebook encontraremos los csvs importados con pandas junto con sus datos básicos y algunas visualizaciones para entenderlo mejor.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # ***SPOTIFY DATA***
# ### Our columns here:
# - name - Name of song
# - album - Name of album
# - artist - Name of artist/s involved
# - release_date - Release date of album
# - length - Song length in milliseconds
# - popularity - Percent popularity of the song based on Spotify's algorithm (possibly the number of stream at a certain period of time)
# - danceability - How suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity
# - acousticness - How acoustic a song is
# - energy - A perceptual measure of intensity and activity
# - instrumentalness - Te amount of vocals in the song
# - liveness - Probability that the song was recorded with a live audience
# - loudness - Tdency o of music to be recorded at steadily higher volumes
# - speechiness - Presence of spoken words in a track (if the speechiness of a song is above 0.66, it is probably made of spoken words, a score between 0.33 and 0.66 is a song that may contain both music and words, and a score below 0.33 means the song does not have any speech)
# - valence - A measure of how happy or sad the song sounds
# - tempo - Beats per minute

# %%
spotaylor= pd.read_csv('Data/spotify_taylorswift.csv')

# %%
spotaylor.head()
# Out:
#    Unnamed: 0                                         name         album  \
# 0           0                                   Tim McGraw  Taylor Swift
# 1           1                              Picture To Burn  Taylor Swift
# 2           2  Teardrops On My Guitar - Radio Single Remix  Taylor Swift
# 3           3                        A Place in this World  Taylor Swift
# 4           4                                  Cold As You  Taylor Swift
#
#          artist release_date  length  popularity  danceability  acousticness  \
# 0  Taylor Swift   2006-10-24  232106          49         0.580         0.575
# 1  Taylor Swift   2006-10-24  173066          54         0.658         0.173
# 2  Taylor Swift   2006-10-24  203040          59         0.621         0.288
# 3  Taylor Swift   2006-10-24  199200          49         0.576         0.051
# 4  Taylor Swift   2006-10-24  239013          50         0.418         0.217
#
# ...

# %%
spotaylor.describe()
# Out:
#        Unnamed: 0         length  popularity  danceability  acousticness  \
# count  171.000000     171.000000  171.000000    171.000000    171.000000
# mean    85.000000  236663.520468   61.228070      0.588632      0.321634
# std     49.507575   40456.720158   11.904548      0.115067      0.334019
# min      0.000000  107133.000000    0.000000      0.292000      0.000191
# 25%     42.500000  211833.000000   58.000000      0.527000      0.030450
# 50%     85.000000  234000.000000   63.000000      0.593000      0.156000
# 75%    127.500000  254447.000000   67.000000      0.655500      0.674000
# max    170.000000  403887.000000   82.000000      0.897000      0.971000
#
#            energy  instrumentalness    liveness    loudness  speechiness  \
# count  171.000000        171.000000  171.000000  171.000000   171.000000
# mean     0.585977          0.002490    0.145927   -7.322111     0.065583
# std      0.189577          0.018766    0.090314    2.878787     0.105956
# ...

# %%
spotaylor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        171 non-null    int64
#  1   name              171 non-null    object
#  2   album             171 non-null    object
#  3   artist            171 non-null    object
#  4   release_date      171 non-null    object
#  5   length            171 non-null    int64
#  6   popularity        171 non-null    int64
#  7   danceability      171 non-null    float64
#  8   acousticness      171 non-null    float64
#  9   energy            171 non-null    float64
#  10  instrumentalness  171 non-null    float64
#  11  liveness          171 non-null    float64
#  12  loudness          171 non-null    float64
#  13  speechiness       171 non-null    float64
#  14  valence           171 non-null    float64
#  15  tempo             171 non-null    float64
# ...

# %%
spotaylor.columns
# Out:
# Index(['Unnamed: 0', 'name', 'album', 'artist', 'release_date', 'length',
#        'popularity', 'danceability', 'acousticness', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence',
#        'tempo'],
#       dtype='object')

# %%
spotaylor.shape
# Out:
# (171, 16)

# %%
# Histogramas para las métricas de Spotify
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.histplot(spotaylor['popularity'], bins=30, kde=True, color='lightcoral')
plt.title('Distribución de Popularidad en Spotify')

plt.subplot(2, 2, 2)
sns.histplot(spotaylor['danceability'], bins=30, kde=True, color='lightcoral')
plt.title('Distribución de Danceability en Spotify')

plt.subplot(2, 2, 3)
sns.histplot(spotaylor['energy'], bins=30, kde=True, color='lightcoral')
plt.title('Distribución de Energy en Spotify')

plt.subplot(2, 2, 4)
sns.histplot(spotaylor['tempo'], bins=30, kde=True, color='lightcoral')
plt.title('Distribución de Tempo en Spotify')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **LYRICS**
#
# ### In this dataset:
#
#  The lyrics have already been cleared of punctuation marks, HTML and formatting. For further work with text data, it's recommended to convert song lyrics to lower case, clear strings of stop words and also lemmatize words.
#
# Description
#
# - Album: The name of the album.
# - Release Date: The release date of the album.
# - Song Title: The short title of the song.
# - Featured Artists: The featured artist(s) on the song.
# - Lyrics: The lyrics of the song.

# %%
lyrics = pd.read_csv('Data/taylor_lyrics.csv')

# %%
lyrics.head()
# Out:
#                    Album Release Date              Song Title  \
# 0  Taylor Swift (Deluxe)   06/11/2007              Tim McGraw
# 1  Taylor Swift (Deluxe)   06/11/2007         Picture to Burn
# 2  Taylor Swift (Deluxe)   06/11/2007  Teardrops On My Guitar
# 3  Taylor Swift (Deluxe)   06/11/2007   A Place In This World
# 4  Taylor Swift (Deluxe)   06/11/2007             Cold as You
#
#   Featured Artists                                             Lyrics
# 0              NaN  He said the way my blue eyes shined Put those ...
# 1              NaN  State the obvious I didn t get my perfect fant...
# 2              NaN  Drew looks at me I fake a smile so he won t se...
# 3              NaN  I don t know what I want so don t ask me Cause...
# 4              NaN  You have a way of coming easily to me And when...

# %%
lyrics.shape
# Out:
# (207, 5)

# %%
lyrics.describe()
# Out:
#                          Album Release Date  Song Title Featured Artists  \
# count                      207          207         207               19
# unique                      10           10         207               17
# top     Red (Taylor’s Version)   12/11/2021  Tim McGraw         Bon Iver
# freq                        31           31           1                2
#
#                                                    Lyrics
# count                                                 207
# unique                                                207
# top     He said the way my blue eyes shined Put those ...
# freq                                                    1

# %%
lyrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Album             207 non-null    object
#  1   Release Date      207 non-null    object
#  2   Song Title        207 non-null    object
#  3   Featured Artists  19 non-null     object
#  4   Lyrics            207 non-null    object
# dtypes: object(5)
# memory usage: 8.2+ KB

# %%
lyrics.columns
# Out:
# Index(['Album', 'Release Date', 'Song Title', 'Featured Artists', 'Lyrics'], dtype='object')

# %%
# Veamos ahora la longitud de las letras
#lyrics['Length'] = lyrics['Lyrics'].apply(len)

# %%
lyrics.head()
# Out:
#                    Album Release Date              Song Title  \
# 0  Taylor Swift (Deluxe)   06/11/2007              Tim McGraw
# 1  Taylor Swift (Deluxe)   06/11/2007         Picture to Burn
# 2  Taylor Swift (Deluxe)   06/11/2007  Teardrops On My Guitar
# 3  Taylor Swift (Deluxe)   06/11/2007   A Place In This World
# 4  Taylor Swift (Deluxe)   06/11/2007             Cold as You
#
#   Featured Artists                                             Lyrics  Length
# 0              NaN  He said the way my blue eyes shined Put those ...    1783
# 1              NaN  State the obvious I didn t get my perfect fant...    1522
# 2              NaN  Drew looks at me I fake a smile so he won t se...    1384
# 3              NaN  I don t know what I want so don t ask me Cause...    1056
# 4              NaN  You have a way of coming easily to me And when...    1211

# %%
# Histograma de Longitud de Letras
plt.figure(figsize=(12, 6))
sns.histplot(lyrics['Length'], bins=30, kde=True, color='skyblue')
plt.title('Distribución de Longitud de Letras')
plt.xlabel('Longitud de Letras')
plt.ylabel('Frecuencia')
plt.show()

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(width=800, height=400, random_state=21, max_font_size=110, background_color='white').generate(' '.join(lyrics['Lyrics']))

# %%
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Nube de Palabras para Letras de Canciones')
plt.show()

# %% [markdown]
# # ***YOUTUBE***

# %% [markdown]
# ### taylor_channel: All videos on TaylorSwiftVEVO channel (last update: 2021.10.08)

# %%
youtailor = pd.read_csv('Data/taylor_channel.csv')

# %%
youtailor.head()
# Out:
#             id                                              title  \
# 0  _9RWI5JBew0    Taylor Swift - Mine (Live, BBC Radio 2 Session)
# 1  _zUCMfYkgj0  Taylor Swift - ME! (Live on The Voice / 2019) ...
# 2  -BjZmE2gtdo                               Taylor Swift - Lover
# 3  -CmadmM5cOk                               Taylor Swift - Style
# 4  1iRbIYkccgw  Taylor Swift - it’s time to go (Official Lyric...
#
#        publication_date                                        description  \
# 0  2011-08-24T11:29:30Z  Shop music here: http://smarturl.it/TASmusic\n...
# 1  2019-05-22T03:00:05Z  ‘folklore’ album out now: https://store.taylor...
# 2  2019-08-22T21:30:09Z  Official music video by Taylor Swift performin...
# 3  2015-02-13T13:20:01Z  ►Exclusive Merch: https://store.taylorswift.co...
# 4  2021-01-07T05:00:01Z  Official lyric video by Taylor Swift performin...
#
#                  channel_id    channel_title  viewCount  likeCount  \
# ...

# %%
youtailor.shape
# Out:
# (197, 12)

# %%
youtailor.describe()
# Out:
#           viewCount     likeCount  dislikeCount  favoriteCount   commentCount
# count  1.970000e+02  1.970000e+02  1.970000e+02          197.0     197.000000
# mean   1.078273e+08  8.068961e+05  4.156145e+04            0.0   45158.802030
# std    3.569389e+08  1.823815e+06  1.464511e+05            0.0  104586.699452
# min    1.285940e+05  3.100000e+02  3.500000e+01            0.0      45.000000
# 25%    3.570871e+06  9.341000e+04  9.420000e+02            0.0    3859.000000
# 50%    9.130310e+06  1.931250e+05  2.378000e+03            0.0    7551.000000
# 75%    3.325855e+07  5.192800e+05  9.196000e+03            0.0   28302.000000
# max    3.103602e+09  1.234282e+07  1.331529e+06            0.0  746368.000000

# %%
youtailor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                197 non-null    object
#  1   title             197 non-null    object
#  2   publication_date  197 non-null    object
#  3   description       197 non-null    object
#  4   channel_id        197 non-null    object
#  5   channel_title     197 non-null    object
#  6   viewCount         197 non-null    int64
#  7   likeCount         197 non-null    int64
#  8   dislikeCount      197 non-null    int64
#  9   favoriteCount     197 non-null    int64
#  10  commentCount      197 non-null    int64
#  11  url               197 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 18.6+ KB

# %%
youtailor.columns
# Out:
# Index(['id', 'title', 'publication_date', 'description', 'channel_id',
#        'channel_title', 'viewCount', 'likeCount', 'dislikeCount',
#        'favoriteCount', 'commentCount', 'url'],
#       dtype='object')

# %%
# Histograms for YouTube metrics
plt.figure(figsize=(15, 10))
#kde para suavizar la lectura
# viewCount
plt.subplot(2, 2, 1)
sns.histplot(youtailor['viewCount'], bins=30, kde=True, color='lightgreen')
plt.title('Distribution of View Count on YouTube')

# likeCount
plt.subplot(2, 2, 2)
sns.histplot(youtailor['likeCount'], bins=30, kde=True, color='lightgreen')
plt.title('Distribution of Like Count on YouTube')

# dislikeCount
plt.subplot(2, 2, 3)
sns.histplot(youtailor['dislikeCount'], bins=10, kde=True, color='lightgreen')
plt.title('Distribution of Dislike Count on YouTube')

# commentCount
plt.subplot(2, 2, 4)
sns.histplot(youtailor['commentCount'], bins=30, kde=True, color='lightgreen')
plt.title('Distribution of Comment Count on YouTube')

plt.tight_layout()
plt.show()

# %%
# Correlation Matrix
plt.figure(figsize=(10, 8))
correlation_matrix = youtailor[['viewCount', 'likeCount', 'dislikeCount', 'commentCount']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Between YouTube Metrics')
plt.show()

# %%
# Scatter plot for Likes vs Dislikes

plt.figure(figsize=(10, 8))
sns.scatterplot(x='likeCount', y='commentCount', data=youtailor, color='blue')
plt.title('Relationship Between Likes and Comments on YouTube')
plt.xlabel('Like Count')
plt.ylabel('Comment Count')
plt.show()
